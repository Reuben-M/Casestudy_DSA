# %%
#import libraries and import the csv file
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_csv('cars_data.csv')

# %% [markdown]
# ## 1. Reading the Dataset

# %%
data.head()
# Out:
#      Make    Model    Nickname Car Gender Buyer Gender  Buyer Age  \
# 0  Suzuki   Vitara  Philippine     Female       Female         51
# 1   Honda    S2000      Henrik       Male         Male         30
# 2     BMW       Z4      Lebbie       Male       Female         54
# 3  Toyota   Tacoma    Jefferey     Female         Male         68
# 4    Ford  Festiva     Glendon     Female         Male         70
#
#         Buzzword   Country             City  Dealer Latitude  \
# 0  User-friendly   Belgium        Antwerpen        51.247239
# 1      analyzing     China            Jinhu        33.025433
# 2       software     China             Gemo        30.916207
# 3     monitoring  Portugal  Queluz de Baixo        38.745168
# 4       Sharable    Latvia         Jaunpils        56.729980
#
#    Dealer Longitude    Color  New Car Purchase Date  Sale Price  Discount  \
# 0          4.440346   Yellow    False    19/07/2009    54806.14    0.2467
# ...

# %% [markdown]
# ## 2.Checking for NULL Values

# %%
data.isna().sum()
# Out:
# Make                 0
# Model                0
# Nickname             0
# Car Gender           0
# Buyer Gender         0
# Buyer Age            0
# Buzzword             0
# Country              0
# City                 0
# Dealer Latitude      0
# Dealer Longitude     0
# Color                0
# New Car              0
# Purchase Date        0
# Sale Price           0
# Discount             0
# Resell Price         0
# 5-yr Depreciation    0
# Top Speed            0
# 0-60 Time            0
# dtype: int64

# %% [markdown]
# ## 3.Male V/S Female buyers

# %%
data['Buyer Gender'].value_counts().plot(kind='bar')
plt.xlabel("Gender")
plt.ylabel("Sale Price")
plt.show()

# %% [markdown]
# ## 4.TOP 5 Cars based on Sale price

# %%
top=data['Sale Price'].sort_values(ascending=False)

# %%
top
# Out:
# 5984    99997.65
# 1270    99991.91
# 3460    99983.38
# 9032    99978.17
# 302     99973.44
#           ...
# 6241    10039.82
# 6270    10024.86
# 5956    10023.85
# 7234    10019.95
# 3513    10003.76
# Name: Sale Price, Length: 10000, dtype: float64

# %%
top5=pd.DataFrame([data.iloc[5984],data.iloc[1270],data.iloc[3460],data.iloc[9032],data.iloc[302]],index=['1','2','3','4','5'])

# %%
top5
# Out:
#          Make      Model   Nickname Car Gender Buyer Gender  Buyer Age  \
# 1  Volkswagen  Jetta III    Rachael     Female       Female         73
# 2        Audi         A6      Thorn       Male         Male         75
# 3       Lexus         LX      Aldin     Female         Male         38
# 4       Mazda       MX-6  Sylvester     Female         Male         26
# 5       Lexus         ES       Brig     Female         Male         39
#
#             Buzzword   Country           City  Dealer Latitude  \
# 1               core    Russia    Krasnoyarka        59.418208
# 2           function    Latvia        Līgatne        57.236340
# 3           software  Malaysia      Pasir Mas         6.109065
# 4  internet solution    Russia  Krutaya Gorka        55.369917
# 5        user-facing    Canada       Langford        48.447463
#
#    Dealer Longitude   Color  New Car Purchase Date  Sale Price  Discount  \
# 1         60.514706    Blue    False    10/05/2014    99997.65    0.1695
# ...

# %% [markdown]
# ## 5.Least 5 Cars based on Resell price

# %%
low=data['Resell Price'].sort_values(ascending=True)

low
# Out:
# 2446     2000.84
# 4933     2005.44
# 566      2014.09
# 2538     2017.24
# 5869     2017.83
#           ...
# 5173    49981.31
# 2512    49984.39
# 222     49988.65
# 8406    49996.96
# 3224    49997.05
# Name: Resell Price, Length: 10000, dtype: float64

# %%
least5=pd.DataFrame([data.iloc[2446],data.iloc[4933],data.iloc[566],data.iloc[2538],data.iloc[5869]],index=['1','2','3','4','5'])

# %%
least5
# Out:
#          Make        Model Nickname Car Gender Buyer Gender  Buyer Age  \
# 1   Chevrolet         1500  Corenda       Male       Female         25
# 2         GMC  Savana 1500     Lark     Female       Female         34
# 3      Jaguar           XF   Payton     Female         Male         64
# 4  Mitsubishi       3000GT     Thia     Female       Female         25
# 5    Infiniti          G37    Sonny       Male         Male         20
#
#          Buzzword      Country              City  Dealer Latitude  \
# 1   collaboration  Philippines           Tubigan         8.490877
# 2     interactive       Poland       Śródmieście        53.838651
# 3       Visionary      Nigeria       Ikot-Ekpene         5.174447
# 4  well-modulated        China        Yanweigang        34.509325
# 5      optimizing       France  Clermont-Ferrand        45.786764
#
#    Dealer Longitude      Color  New Car Purchase Date  Sale Price  Discount  \
# ...
